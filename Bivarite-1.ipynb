# %%
import pandas as pd
dataset=pd.read_csv("PrePlacement.csv")
dataset.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       0.0
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %% [markdown]
# # Covariance

# %%
dataset.drop('sl_no', inplace = True, axis =1)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# 0       No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1      Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2       No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3       No     66.0         Mkt&HR  59.43  Not Placed       0.0
# 4       No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..     ...      ...            ...    ...         ...       ...
# 210     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214     No     89.0         Mkt&HR  60.22  Not Placed       0.0
#
# [215 rows x 14 columns]

# %%
from Univariate import Univariate
quan,qual = Univariate.quanQual(dataset)
quan
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
dataset[quan].cov()
# Out:
#                   ssc_p          hsc_p       degree_p        etest_p  \
# ssc_p        117.228377      58.853253      42.702550      37.659225
# hsc_p         58.853253     112.063731      33.684453      33.838355
# degree_p      42.702550      33.684453      53.604710      22.078774
# etest_p       37.659225      33.838355      22.078774     176.251018
# mba_p         24.535952      21.517688      17.185200      16.886973
# salary    908858.485818  731007.850848  466336.264888  372700.449468
#
#                   mba_p        salary
# ssc_p         24.535952  9.088585e+05
# hsc_p         21.517688  7.310079e+05
# degree_p      17.185200  4.663363e+05
# etest_p       16.886973  3.727004e+05
# mba_p         34.028376  1.239934e+05
# salary    123993.387361  2.259185e+10

# %% [markdown]
# # Correlation

# %%
dataset[quan].corr()
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.513478  0.538686  0.261993  0.388478  0.558475
# hsc_p     0.513478  1.000000  0.434606  0.240775  0.348452  0.459424
# degree_p  0.538686  0.434606  1.000000  0.227147  0.402376  0.423762
# etest_p   0.261993  0.240775  0.227147  1.000000  0.218055  0.186775
# mba_p     0.388478  0.348452  0.402376  0.218055  1.000000  0.141417
# salary    0.558475  0.459424  0.423762  0.186775  0.141417  1.000000

# %%
dataset.corrwith(dataset[quan])
# Out:
# ssc_p             1.0
# hsc_p             1.0
# degree_p          1.0
# etest_p           1.0
# mba_p             1.0
# salary            1.0
# degree_t          NaN
# gender            NaN
# hsc_b             NaN
# hsc_s             NaN
# specialisation    NaN
# ssc_b             NaN
# status            NaN
# workex            NaN
# dtype: float64

# %% [markdown]
# # Preprocessing

# %%
#dataset=dataset.drop(columns='sl_no')
#dataset=dataset.dropna()

# %% [markdown]
# # Visulaize the pair

# %%
import seaborn as sns
sns.pairplot(dataset,hue="ssc_b")

import matplotlib.pyplot as plt
plt.savefig('pairplot_ssc_b.png')

# %% [markdown]
# # Calling user defined function Descriptive file

# %% [markdown]
# # Sregrating quantitative Data and qualtative

# %%
quan,qual
# Out:
# (['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
quan_data=dataset[quan]

# %%
quan_data
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0    67.00  91.00     58.00     55.0  58.80  270000.0
# 1    79.33  78.33     77.48     86.5  66.28  200000.0
# 2    65.00  68.00     64.00     75.0  57.80  250000.0
# 3    56.00  52.00     52.00     66.0  59.43       0.0
# 4    85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...       ...      ...    ...       ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.0
# 211  58.00  60.00     72.00     74.0  53.62  275000.0
# 212  67.00  67.00     73.00     59.0  69.72  295000.0
# 213  74.00  66.00     58.00     70.0  60.23  204000.0
# 214  62.00  58.00     53.00     89.0  60.22       0.0
#
# [215 rows x 6 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
calc_vif(quan_data)
# Out:
#   variables         VIF
# 0     ssc_p   78.168671
# 1     hsc_p   61.882196
# 2  degree_p  114.820554
# 3   etest_p   32.720365
# 4     mba_p  116.034378
# 5    salary    4.171783

# %%
quan_data=dataset[['etest_p','salary',]]

# %%
quan_data
# Out:
#      etest_p    salary
# 0       55.0  270000.0
# 1       86.5  200000.0
# 2       75.0  250000.0
# 3       66.0       0.0
# 4       96.8  425000.0
# ..       ...       ...
# 210     91.0  400000.0
# 211     74.0  275000.0
# 212     59.0  295000.0
# 213     70.0  204000.0
# 214     89.0       0.0
#
# [215 rows x 2 columns]

# %% [markdown]
# # Univarite Analysis

# %% [markdown]
# ## Probability Density Function(PDF)

# %%
# Density Polt

import seaborn as sns
x=dataset['ssc_p']
ax = sns.distplot(dataset['ssc_p'],kde=True)
# Out:
# C:\Users\YAS\AppData\Local\Temp\ipykernel_12480\1045121082.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset['ssc_p'],kde=True)

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset['ssc_p'],60,60)
# Out:
# C:\Users\YAS\AppData\Local\Temp\ipykernel_12480\2842244316.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=67.303, Standard Deviation=10.827
# The area between range(60,60):0
# 0

# %% [markdown]
# # cumulative Density function

# %%
import matplotlib.pyplot as plt
x=dataset['ssc_p']
plt.hist(x,cumulative=True, density=True,bins=10)
# Out:
# (array([0.02325581, 0.05581395, 0.15813953, 0.24651163, 0.44651163,
#         0.59534884, 0.73023256, 0.85116279, 0.95348837, 1.        ]),
#  array([40.89 , 45.741, 50.592, 55.443, 60.294, 65.145, 69.996, 74.847,
#         79.698, 84.549, 89.4  ]),
#  <BarContainer object of 10 artists>)

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(dataset['ssc_p'])
ecdf()
# Out:
# 0.9674418604651163

# %% [markdown]
# # Types of Test

# %% [markdown]
# # Z- Score: Normal distribution to Standard Normal Distribution

# %%
# Normal Distribution
import seaborn as sns
sns.distplot(dataset['ssc_p'],kde=True)
# Out:
# C:\Users\YAS\AppData\Local\Temp\ipykernel_12480\2856391435.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['ssc_p'],kde=True)
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
# Coverted to standard Normal Distribution
import seaborn as sns
mean=dataset['ssc_p'].mean()
std=dataset['ssc_p'].std()

values=[i for i in dataset['ssc_p']]

z_score=[((j-mean)/std) for j in values]

sns.distplot(z_score,kde=True)

sum(z_score)/len(z_score)
#z_score.std()
# Out:
# C:\Users\YAS\AppData\Local\Temp\ipykernel_12480\2041011225.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)
# -4.2911410858767677e-16

# %%
dataset[dataset["gender"] == 'M']
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 209      M  62.00  Central  72.00  Central  Commerce     65.00  Comm&Mgmt
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# 0       No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1      Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2       No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3       No     66.0         Mkt&HR  59.43  Not Placed       0.0
# 4       No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..     ...      ...            ...    ...         ...       ...
# 209     No     67.0        Mkt&Fin  56.49      Placed  216000.0
# 210     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 214     No     89.0         Mkt&HR  60.22  Not Placed       0.0
#
# [139 rows x 14 columns]

# %% [markdown]
# # T-Test

# %% [markdown]
# #### Independant Sample
# Diferrent Group(Male, Female) but same contion(salary)

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['salary']
female = dataset[dataset['gender']=='F']['salary']
#print(male)
ttest_ind(male, female)
# Out:
# TtestResult(statistic=2.0937842507001165, pvalue=0.03746230397067219, df=213.0)

# %% [markdown]
# #### Dependant Sample
# Same Group(Male) but Different Condition(ssc_p,hsc_p)

# %%
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['ssc_p']
male1 = dataset[dataset['gender']=='M']['hsc_p']
ttest_rel(male, male1)
# Out:
# TtestResult(statistic=0.6842940392688153, pvalue=0.4949370716000775, df=138)

# %% [markdown]
# ### for one sample mean
#
# should same for different sample
#
# scipy.stats.ttest_1samp(a, popmean, axis=0, nan_policy='propagate')

# %% [markdown]
# # ANAVO : Analysis of Variance

# %% [markdown]
# ## One-Way Classification

# %%
import scipy.stats as stats

stats.f_oneway(dataset['ssc_p'],dataset['hsc_p'],dataset['degree_p'])
# Out:
# F_onewayResult(statistic=0.695991304348204, pvalue=0.4989557472581533)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Assuming 'salary' is the dependent variable and 'workex' and 'degree_t' are the factors
model_formula = 'salary ~ ssc_p* hsc_p '

# Create a model from the formula and data (assuming you have a dataset)
model = ols(formula=model_formula, data=dataset).fit()

# Perform the two-way ANOVA
sm.stats.anova_lm(model, typ=2)
# Out:
#                    sum_sq     df          F        PR(>F)
# ssc_p        6.831853e+11    1.0  46.889814  8.057781e-11
# hsc_p        1.957342e+11    1.0  13.434045  3.126504e-04
# ssc_p:hsc_p  5.674433e+10    1.0   3.894597  4.974688e-02
# Residual     3.074273e+12  211.0        NaN           NaN

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

#perform two-way ANOVA
model = ols(model_formula = 'salary ~ ssc_p* hsc_p ', data=dataset).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 5
#       2 from statsmodels.formula.api import ols
#       4 #perform two-way ANOVA
# ----> 5 model = ols(model_formula = 'salary ~ ssc_p* hsc_p ', data=dataset).fit()
#       6 sm.stats.anova_lm(model, typ=2)
#
# TypeError: Model.from_formula() missing 1 required positional argument: 'formula'
